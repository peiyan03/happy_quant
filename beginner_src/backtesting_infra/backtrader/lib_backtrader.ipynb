# %%
# import sys
# print(sys.executable)
# print(sys.version)
# Out:
# c:\Users\peiya\AppData\Local\Programs\Python\Python39\python.exe
# 3.9.0 (tags/v3.9.0:9cf6752, Oct  5 2020, 15:34:40) [MSC v.1927 64 bit (AMD64)]

# %%
from datetime import datetime
import backtrader as bt

# %%
from datetime import datetime
import backtrader as bt

class SmaCross(bt.SignalStrategy):
    def __init__(self):
        sma1, sma2 = bt.ind.SMA(period=10), bt.ind.SMA(period=30)
        crossover = bt.ind.CrossOver(sma1, sma2)
        self.signal_add(bt.SIGNAL_LONG, crossover)

cerebro = bt.Cerebro()
cerebro.addstrategy(SmaCross)

data0 = bt.feeds.YahooFinanceData(dataname='MSFT', fromdate=datetime(2011, 1, 1),
                                  todate=datetime(2012, 12, 31))
cerebro.adddata(data0)

cerebro.run()
cerebro.plot()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:485, in BaseHTTPResponse._decode(self, data, decode_content, flush_decoder)
#     484 if self._decoder:
# --> 485     data = self._decoder.decompress(data)
#     486     self._has_decoded_content = True
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:128, in GzipDecoder.decompress(self, data)
#     127 try:
# --> 128     ret += self._obj.decompress(data)
#     129 except zlib.error:
#
# error: Error -3 while decompressing data: incorrect header check
#
# The above exception was the direct cause of the following exception:
#
# DecodeError                               Traceback (most recent call last)
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:1223, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1222 chunk = self._handle_chunk(amt)
# -> 1223 decoded = self._decode(
#    1224     chunk, decode_content=decode_content, flush_decoder=False
#    1225 )
#    1226 if decoded:
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py:489, in BaseHTTPResponse._decode(self, data, decode_content, flush_decoder)
#     488     content_encoding = self.headers.get("content-encoding", "").lower()
# --> 489     raise DecodeError(
#     490         "Received response with content-encoding: %s, but "
#     491         "failed to decode it." % content_encoding,
#     492         e,
#     493     ) from e
#     494 if flush_decoder:
#
# DecodeError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))
#
# During handling of the above exception, another exception occurred:
#
# ContentDecodingError                      Traceback (most recent call last)
# Cell In[2], line 17
#      13 data0 = bt.feeds.YahooFinanceData(dataname='MSFT', fromdate=datetime(2011, 1, 1),
#      14                                   todate=datetime(2012, 12, 31))
#      15 cerebro.adddata(data0)
# ---> 17 cerebro.run()
#      18 cerebro.plot()
#
# File F:\_main_code_src\src\quant_home\happy_quant\py_backtrader\pzou_backtrader\backtrader\cerebro.py:1132, in Cerebro.run(self, **kwargs)
#    1128 if not self._dooptimize or self.p.maxcpus == 1:
#    1129     # If no optimmization is wished ... or 1 core is to be used
#    1130     # let's skip process "spawning"
#    1131     for iterstrat in iterstrats:
# -> 1132         runstrat = self.runstrategies(iterstrat)
#    1133         self.runstrats.append(runstrat)
#    1134         if self._dooptimize:
#
# File F:\_main_code_src\src\quant_home\happy_quant\py_backtrader\pzou_backtrader\backtrader\cerebro.py:1215, in Cerebro.runstrategies(self, iterstrat, predata)
#    1213 if self._exactbars < 1:  # datas can be full length
#    1214     data.extend(size=self.params.lookahead)
# -> 1215 data._start()
#    1216 if self._dopreload:
#    1217     data.preload()
#
# File F:\_main_code_src\src\quant_home\happy_quant\py_backtrader\pzou_backtrader\backtrader\feed.py:203, in AbstractDataBase._start(self)
#     202 def _start(self):
# --> 203     self.start()
#     205     if not self._started:
#     206         self._start_finish()
#
# File F:\_main_code_src\src\quant_home\happy_quant\py_backtrader\pzou_backtrader\backtrader\feeds\yahoo.py:353, in YahooFinanceData.start(self)
#     352 def start(self):
# --> 353     self.start_v7()
#     355     # Prepared a "path" file -  CSV Parser can take over
#     356     super(YahooFinanceData, self).start()
#
# File F:\_main_code_src\src\quant_home\happy_quant\py_backtrader\pzou_backtrader\backtrader\feeds\yahoo.py:273, in YahooFinanceData.start_v7(self)
#     271 sess.headers['User-Agent'] = 'backtrader'
#     272 for i in range(self.p.retries + 1):  # at least once
# --> 273     resp = sess.get(url, **sesskwargs)
#     274     if resp.status_code != requests.codes.ok:
#     275         continue
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File c:\Users\peiya\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:824, in Response.iter_content.<locals>.generate()
#     822     raise ChunkedEncodingError(e)
#     823 except DecodeError as e:
# --> 824     raise ContentDecodingError(e)
#     825 except ReadTimeoutError as e:
#     826     raise ConnectionError(e)
#
# ContentDecodingError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))
